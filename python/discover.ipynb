# %%
import sys
sys.path
# Out:
# ['/Users/zhikai/Dvorak/python',
#  '/Users/zhikai/.vscode/extensions/ms-toolsai.jupyter-2021.2.603412351/pythonFiles/vscode_datascience_helpers/../.does-not-exist',
#  '/Users/zhikai/.vscode/extensions/ms-toolsai.jupyter-2021.2.603412351/pythonFiles',
#  '/Users/zhikai/.vscode/extensions/ms-toolsai.jupyter-2021.2.603412351/pythonFiles/lib/python',
#  '/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python38.zip',
#  '/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8',
#  '/Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/lib-dynload',
#  '',
#  '/Users/zhikai/.envs/test/lib/python3.8/site-packages',
#  '/Users/zhikai/.envs/test/lib/python3.8/site-packages/IPython/extensions',
#  '/Users/zhikai/.ipython']

# %%
import pandas as pd
stops_file = 'data/stops.tsv'
pair_file = 'data/pairs.tsv'
df_s = pd.read_csv(stops_file, sep='\t', header=None)
df_p = pd.read_csv(pair_file, sep='\t', header=None)

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn')
plt.rcParams['font.sans-serif'] = ['Arial Unicode MS']
# fig = plt.figure(figsize=(10,15))
plt.scatter(df_s.iloc[:, 2], df_s.iloc[:, 3])
for ind in range(len(df_s)):
    if ind % 10 == 0:
        plt.text(df_s.iloc[ind, 2], df_s.iloc[ind, 3], df_s.iloc[ind, 1])
# plt.savefig('stop_xy.png')

# %%
df_s.head()
# Out:
#             0              1           2          3
# 0  BV11382838     天健三路·周公大道口  108.690421  34.395582
# 1  BV11372635           秦兴佳苑  108.696623  34.399123
# 2  BV11382839     天健三路·周礼四路口  108.707118  34.401606
# 3  BV11382837  西安宝能新能源汽车产业园西  108.705872  34.412865
# 4  BV11375562   西安宝能新能源汽车产业园  108.716029  34.414319

# %%
max_lng, min_lng = df_s.iloc[:, 2].max(), df_s.iloc[:, 2].min()
max_lat, min_lat = df_s.iloc[:, 3].max(), df_s.iloc[:, 3].min()

# %%
import numpy as np 
np.random.uniform(min_lng, max_lng)
# Out:
# 108.60691614328802

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-110d55cd3c5a> in <module>
# ----> 1 df_p.tolist()
#
# ~/.envs/test/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5460             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5461                 return self[name]
# -> 5462             return object.__getattribute__(self, name)
#    5463
#    5464     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'tolist'
